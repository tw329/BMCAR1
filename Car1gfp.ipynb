# %%
import scanpy as sc

# %%
adata = sc.read_10x_mtx('./Downloads/GSE131059_RAW/Car1gfp/', cache_compression=None)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2522 × 27998
#     var: 'gene_ids'

# %%
sc.pp.calculate_qc_metrics (adata)
# Out:
# (                    n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
#  AAACCTGCAAGCCGTC-1               4346                 8.377241       25021.0
#  AAACCTGCATTGTGCA-1               4719                 8.459564       35369.0
#  AAACCTGGTACCAGTT-1               1652                 7.410347        4798.0
#  AAACCTGGTATATGAG-1               4624                 8.439232       29448.0
#  AAACGGGAGATAGCAT-1               2026                 7.614312        6169.0
#  ...                               ...                      ...           ...
#  TTTGGTTCAATGGAAT-1               4213                 8.346168       24400.0
#  TTTGGTTGTTATCGGT-1               3721                 8.222016       19730.0
#  TTTGGTTTCTTGCCGT-1               5110                 8.539150       34609.0
#  TTTGTCAGTATTACCG-1               4212                 8.345930       26044.0
#  TTTGTCAGTCATATCG-1               2461                 7.808729        7909.0
#
#                      log1p_total_counts  pct_counts_in_top_50_genes  \
#  AAACCTGCAAGCCGTC-1           10.127511                   29.958835
#  AAACCTGCATTGTGCA-1           10.473619                   28.024541
#  AAACCTGGTACCAGTT-1            8.476163                   36.431847
#  AAACCTGGTATATGAG-1           10.290415                   27.883048
#  AAACGGGAGATAGCAT-1            8.727454                   35.645972
#  ...                                ...                         ...
#  TTTGGTTCAATGGAAT-1           10.102380                   28.557377
#  TTTGGTTGTTATCGGT-1            9.889946                   29.822605
#  TTTGGTTTCTTGCCGT-1           10.451898                   26.198388
#  TTTGTCAGTATTACCG-1           10.167582                   30.901551
#  TTTGTCAGTCATATCG-1            8.975883                   30.206094
#
#                      pct_counts_in_top_100_genes  pct_counts_in_top_200_genes  \
#  AAACCTGCAAGCCGTC-1                    43.619360                    54.722033
#  AAACCTGCATTGTGCA-1                    41.875654                    54.327236
#  AAACCTGGTACCAGTT-1                    50.646103                    60.962901
#  AAACCTGGTATATGAG-1                    40.848275                    52.373676
#  AAACGGGAGATAGCAT-1                    46.571568                    56.929810
#  ...                                         ...                          ...
#  TTTGGTTCAATGGAAT-1                    41.815574                    53.627049
#  TTTGGTTGTTATCGGT-1                    44.308160                    55.930056
#  TTTGGTTTCTTGCCGT-1                    38.859834                    50.151695
#  TTTGTCAGTATTACCG-1                    46.041315                    57.721548
#  TTTGTCAGTCATATCG-1                    42.508535                    53.243141
#
#                      pct_counts_in_top_500_genes
#  AAACCTGCAAGCCGTC-1                    67.906958
#  AAACCTGCATTGTGCA-1                    68.034154
#  AAACCTGGTACCAGTT-1                    75.218841
#  AAACCTGGTATATGAG-1                    66.245585
#  AAACGGGAGATAGCAT-1                    71.259523
#  ...                                         ...
#  TTTGGTTCAATGGAAT-1                    67.770492
#  TTTGGTTGTTATCGGT-1                    69.584389
#  TTTGGTTTCTTGCCGT-1                    64.228958
#  TTTGTCAGTATTACCG-1                    70.691906
#  TTTGTCAGTCATATCG-1                    67.935264
#
#  [2522 rows x 8 columns],
#                  n_cells_by_counts  mean_counts  log1p_mean_counts  \
#  Xkr4                            0     0.000000           0.000000
#  Gm1992                          0     0.000000           0.000000
#  Gm37381                         0     0.000000           0.000000
#  Rp1                             0     0.000000           0.000000
#  Rp1-1                           0     0.000000           0.000000
#  ...                           ...          ...                ...
#  AC168977.1                     10     0.003965           0.003957
#  PISD                         1457     0.967486           0.676757
#  DHRSX                         985     0.571372           0.451949
#  Vmn2r122                        0     0.000000           0.000000
#  CAAA01147332.1                 18     0.007137           0.007112
#
#                  pct_dropout_by_counts  total_counts  log1p_total_counts
#  Xkr4                       100.000000           0.0            0.000000
#  Gm1992                     100.000000           0.0            0.000000
#  Gm37381                    100.000000           0.0            0.000000
#  Rp1                        100.000000           0.0            0.000000
#  Rp1-1                      100.000000           0.0            0.000000
#  ...                               ...           ...                 ...
#  AC168977.1                  99.603489          10.0            2.397895
#  PISD                        42.228390        2440.0            7.800163
#  DHRSX                       60.943695        1441.0            7.273787
#  Vmn2r122                   100.000000           0.0            0.000000
#  CAAA01147332.1              99.286281          18.0            2.944439
#
#  [27998 rows x 6 columns])

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-') 
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata.n_obs
# Out:
# 2522
